# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras import applications, optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Input
from keras.applications.vgg16 import vgg16, preprocess_input
from keras.utils import to_categorical
from keras.models import *
from keras.regularizers import l2
from keras.layers import *
import numpy as np
import keras
import h5py
import functools
ile_ras = 40

# %%
cd gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# Out:
# mv: missing destination file operand after 'CASE2/case2_history.npy'
# Try 'mv --help' for more information.

# %%
hf = h5py.File('XYtrain_test.h5', 'r')
x_train = hf.get('x_train')
y_train = hf.get('y_train')
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = hf.get('x_test')
y_test = hf.get('y_test')
x_test = np.array(x_test)
y_test = np.array(y_test)
hf.close()

# %%
top5_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=5)

top5_acc.__name__ = 'top5_acc'

# %%
img_width, img_height = 224, 224
model = applications.VGG16(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))
#for layer in model.layers[:-2]:
#   layer.trainable = False

#Adding custom Layers 
x = model.output
x = Flatten()(x)
x = Dense(4096, activation="relu")(x)
x = Dense(4096, activation="relu")(x)
predictions = Dense(40, activation="softmax")(x)

# creating the final model 
model_final = Model(input = model.input, output = predictions)

# compile the model 
model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy",top5_acc])

model_final.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                163880
# =================================================================
# Total params: 134,424,424
# Trainable params: 134,424,424
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
for l in model_final.layers:
    print(l.name, l.trainable)
# Out:
# input_2 False
# block1_conv1 True
# block1_conv2 True
# block1_pool True
# block2_conv1 True
# block2_conv2 True
# block2_pool True
# block3_conv1 True
# block3_conv2 True
# block3_conv3 True
# block3_pool True
# block4_conv1 True
# block4_conv2 True
# block4_conv3 True
# block4_pool True
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True
# flatten_2 True
# dense_4 True
# dense_5 True
# dense_6 True

# %%
epochs = 50

# %%
print(learning.history.keys())
plt.plot(learning.history['acc'])
plt.plot(learning.history['top5_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-983bed54c3ac> in <module>()
# ----> 1 print(learning.history.keys())
#       2 plt.plot(learning.history['acc'])
#       3 plt.plot(learning.history['top5_acc'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'learning' is not defined

# %%
model_final.load_weights('CASE3/case3a_weights.h5')

# %%
model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy",top5_acc])

# %%
x = model_final.layers[-5].output          
x = Flatten()(x)
x = Dense(40, W_regularizer=l2(0.01))(x)
predictions = Activation('exponential')(x)

# creating the final model 
model_final = Model(input = model_final.input, output = predictions)

# compile the model 

for layer in model_final.layers[:-2]:
    layer.trainable = False
model_final.compile(loss='categorical_hinge',optimizer='adadelta',metrics=['accuracy',top5_acc])
model_final.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 40)                1003560
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# =================================================================
# Total params: 15,718,248
# Trainable params: 1,003,560
# Non-trainable params: 14,714,688
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(40, kernel_regularizer=<keras.reg...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
#   import sys

# %%
learning = model_final.fit(x_train, y_train, epochs=epochs, batch_size = 32,validation_split=0.1)
y_train = None
x_train = None
# Out:
# W0618 19:31:18.715101 140495074371456 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 5253 samples, validate on 584 samples
# Epoch 1/50
# 5253/5253 [==============================] - 36s 7ms/step - loss: 25.6370 - acc: 0.3337 - top5_acc: 0.6653 - val_loss: 30.4914 - val_acc: 0.3048 - val_top5_acc: 0.7654
# Epoch 2/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 8.3698 - acc: 0.6511 - top5_acc: 0.9324 - val_loss: 25.7473 - val_acc: 0.3682 - val_top5_acc: 0.7860
# Epoch 3/50
# 5253/5253 [==============================] - 30s 6ms/step - loss: 5.1449 - acc: 0.7647 - top5_acc: 0.9735 - val_loss: 20.1726 - val_acc: 0.4332 - val_top5_acc: 0.8442
# Epoch 4/50
# 5253/5253 [==============================] - 29s 5ms/step - loss: 3.7465 - acc: 0.8273 - top5_acc: 0.9876 - val_loss: 16.3487 - val_acc: 0.4914 - val_top5_acc: 0.8527
# Epoch 5/50
# 5253/5253 [==============================] - 29s 5ms/step - loss: 2.9759 - acc: 0.8656 - top5_acc: 0.9939 - val_loss: 10.8606 - val_acc: 0.5993 - val_top5_acc: 0.9007
# Epoch 6/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 2.6068 - acc: 0.8856 - top5_acc: 0.9958 - val_loss: 12.8568 - val_acc: 0.5685 - val_top5_acc: 0.8921
# Epoch 7/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 2.2936 - acc: 0.9022 - top5_acc: 0.9962 - val_loss: 11.2104 - val_acc: 0.5839 - val_top5_acc: 0.9075
# Epoch 8/50
# 5253/5253 [==============================] - 29s 6ms/step - loss:
50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.3873 - acc: 0.9421 - top5_acc: 0.9987 - val_loss: 10.7187 - val_acc: 0.5925 - val_top5_acc: 0.9195
# Epoch 32/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4622 - acc: 0.9355 - top5_acc: 0.9983 - val_loss: 10.7410 - val_acc: 0.6182 - val_top5_acc: 0.9349
# Epoch 33/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4566 - acc: 0.9328 - top5_acc: 0.9989 - val_loss: 11.9584 - val_acc: 0.5771 - val_top5_acc: 0.9092
# Epoch 34/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4761 - acc: 0.9379 - top5_acc: 0.9983 - val_loss: 11.0858 - val_acc: 0.6113 - val_top5_acc: 0.8990
# Epoch 35/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.3652 - acc: 0.9419 - top5_acc: 0.9989 - val_loss: 10.5906 - val_acc: 0.5908 - val_top5_acc: 0.9229
# Epoch 36/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4861 - acc: 0.9360 - top5_acc: 0.9992 - val_loss: 11.4250 - val_acc: 0.5976 - val_top5_acc: 0.9161
# Epoch 37/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.5300 - acc: 0.9326 - top5_acc: 0.9992 - val_loss: 9.9470 - val_acc: 0.6387 - val_top5_acc: 0.9229
# Epoch 38/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.5279 - acc: 0.9347 - top5_acc: 0.9987 - val_loss: 11.8990 - val_acc: 0.5788 - val_top5_acc: 0.8990
# Epoch 39/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.5930 - acc: 0.9311 - top5_acc: 0.9989 - val_loss: 10.2754 - val_acc: 0.6267 - val_top5_acc: 0.9229
# Epoch 40/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.3837 - acc: 0.9389 - top5_acc: 0.9985 - val_loss: 9.8982 - val_acc: 0.6147 - val_top5_acc: 0.9092
# Epoch 41/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4683 - acc: 0.9328 - top5_acc: 0.9989 - val_loss: 13.4272 - val_acc: 0.5582 - val_top5_acc: 0.9058
# Epoch 42/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.5064 - acc: 0.9336 - top5_acc: 0.9989 - val_loss: 10.5485 - val_acc: 0.5959 - val_top5_acc: 0.9178
# Epoch 43/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.3235 - acc: 0.9465 - top5_acc: 0.9992 - val_loss: 12.2714 - val_acc: 0.5856 - val_top5_acc: 0.9058
# Epoch 44/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.5153 - acc: 0.9317 - top5_acc: 0.9981 - val_loss: 11.6768 - val_acc: 0.5753 - val_top5_acc: 0.9110
# Epoch 45/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4017 - acc: 0.9406 - top5_acc: 0.9987 - val_loss: 14.3147 - val_acc: 0.5616 - val_top5_acc: 0.8904
# Epoch 46/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4326 - acc: 0.9349 - top5_acc: 0.9992 - val_loss: 11.0092 - val_acc: 0.5942 - val_top5_acc: 0.9161
# Epoch 47/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4972 - acc: 0.9332 - top5_acc: 0.9979 - val_loss: 12.3435 - val_acc: 0.5736 - val_top5_acc: 0.8990
# Epoch 48/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.5264 - acc: 0.9338 - top5_acc: 0.9983 - val_loss: 12.8987 - val_acc: 0.5668 - val_top5_acc: 0.9041
# Epoch 49/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.3665 - acc: 0.9419 - top5_acc: 0.9987 - val_loss: 10.5790 - val_acc: 0.6079 - val_top5_acc: 0.9178
# Epoch 50/50
# 5253/5253 [==============================] - 29s 6ms/step - loss: 1.4789 - acc: 0.9355 - top5_acc: 0.9979 - val_loss: 10.6283 - val_acc: 0.5908 - val_top5_acc: 0.9161

# %%
model_final.save_weights('case4_full_exp_weights.h5')

# %%
y_test = to_categorical(y_test)

# %%
score = model_final.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 1460/1460 [==============================] - 7s 5ms/step
# Test loss: nan
# Test accuracy: 0.06986301371904269

# %%
eval = np.c_[score[0],score[1],score[2]]
sc = np.array(eval)
np.savetxt("case4__full_exp_evaluate.txt", sc, delimiter=";")

# %%
history1 = np.c_[learning.history["loss"],learning.history['val_acc'],learning.history['val_top5_acc']]
hist = np.array(history1)
np.savetxt("case4__full_exp_hist1.txt", hist, delimiter=";")
