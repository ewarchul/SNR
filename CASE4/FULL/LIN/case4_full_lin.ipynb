# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from keras import applications, optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Input
from keras.applications.vgg16 import vgg16, preprocess_input
from keras.utils import to_categorical
from keras.models import *
from keras.regularizers import l2
from keras.layers import *
import numpy as np
import keras
import h5py
import functools
ile_ras = 40

# %%
cd gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# Out:
# mv: missing destination file operand after 'CASE2/case2_history.npy'
# Try 'mv --help' for more information.

# %%
hf = h5py.File('XYtrain_test.h5', 'r')
x_train = hf.get('x_train')
y_train = hf.get('y_train')
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = hf.get('x_test')
y_test = hf.get('y_test')
x_test = np.array(x_test)
y_test = np.array(y_test)
hf.close()

# %%
top5_acc = functools.partial(keras.metrics.top_k_categorical_accuracy, k=5)

top5_acc.__name__ = 'top5_acc'

# %%
img_width, img_height = 224, 224
model = applications.VGG16(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))
#for layer in model.layers[:-2]:
#   layer.trainable = False

#Adding custom Layers 
x = model.output
x = Flatten()(x)
x = Dense(4096, activation="relu")(x)
x = Dense(4096, activation="relu")(x)
predictions = Dense(40, activation="softmax")(x)

# creating the final model 
model_final = Model(input = model.input, output = predictions)

# compile the model 
model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy",top5_acc])

model_final.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                163880
# =================================================================
# Total params: 134,424,424
# Trainable params: 134,424,424
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
for l in model_final.layers:
    print(l.name, l.trainable)
# Out:
# input_2 False
# block1_conv1 True
# block1_conv2 True
# block1_pool True
# block2_conv1 True
# block2_conv2 True
# block2_pool True
# block3_conv1 True
# block3_conv2 True
# block3_conv3 True
# block3_pool True
# block4_conv1 True
# block4_conv2 True
# block4_conv3 True
# block4_pool True
# block5_conv1 True
# block5_conv2 True
# block5_conv3 True
# block5_pool True
# flatten_2 True
# dense_4 True
# dense_5 True
# dense_6 True

# %%
epochs = 50

# %%
print(learning.history.keys())
plt.plot(learning.history['acc'])
plt.plot(learning.history['top5_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-983bed54c3ac> in <module>()
# ----> 1 print(learning.history.keys())
#       2 plt.plot(learning.history['acc'])
#       3 plt.plot(learning.history['top5_acc'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'learning' is not defined

# %%
model_final.load_weights('CASE3/case3a_weights.h5')

# %%
model_final.compile(loss = "categorical_crossentropy", optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), metrics=["accuracy",top5_acc])

# %%
x = model_final.layers[-5].output          
x = Flatten()(x)
x = Dense(40, W_regularizer=l2(0.01))(x)
predictions = Activation('linear')(x)

# creating the final model 
model_final = Model(input = model_final.input, output = predictions)

# compile the model 

for layer in model_final.layers[:-2]:
    layer.trainable = False
model_final.compile(loss='categorical_hinge',optimizer='adadelta',metrics=['accuracy',top5_acc])
model_final.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 40)                1003560
# _________________________________________________________________
# activation_1 (Activation)    (None, 40)                0
# =================================================================
# Total params: 15,718,248
# Trainable params: 1,003,560
# Non-trainable params: 14,714,688
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(40, kernel_regularizer=<keras.reg...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
#   import sys

# %%
learning = model_final.fit(x_train, y_train, epochs=epochs, batch_size = 32,validation_split=0.1)
y_train = None
x_train = None
# Out:
# Epoch 1/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0469 - top5_acc: 0.0019
# Epoch 2/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0411 - top5_acc: 0.0000e+00
# Epoch 3/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0421 - top5_acc: 0.0000e+00
# Epoch 4/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0425 - top5_acc: 0.0000e+00
# Epoch 5/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0408 - top5_acc: 0.0000e+00
# Epoch 6/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0432 - top5_acc: 0.0000e+00
# Epoch 7/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0553 - top5_acc: 0.0000e+00
# Epoch 8/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0666 - top5_acc: 0.0000e+00
# Epoch 9/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0665 - top5_acc: 0.0000e+00
# Epoch 10/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0663 - top5_acc: 0.0000e+00
# Epoch 11/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0661 - top5_acc: 0.0000e+00
# Epoch 12/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0661 - top5_acc: 0.0000e+00
# Epoch 13/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0661 - top5_acc: 0.0000e+00
# Epoch 14/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0658 - top5_acc: 0.0000e+00
# Epoch 15/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0656 - top5_acc: 0.0000e+00
# Epoch 16/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0653 - top5_acc: 0.0000e+00
# Epoch 17/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0653 - top5_acc: 0.0000e+00
# Epoch 18/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0653 - top5_acc: 0.0000e+00
# Epoch 19/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0653 - top5_acc: 0.0000e+00
# Epoch 20/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0651 - top5_acc: 0.0000e+00
# Epoch 21/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0651 - top5_acc: 0.0000e+00
# Epoch 22/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0651 - top5_acc: 0.0000e+00
# Epoch 23/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 24/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 25/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 26/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 27/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 28/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 29/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 30/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 31/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 32/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 33/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0648 - top5_acc: 0.0000e+00
# Epoch 34/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0648 - top5_acc: 0.0000e+00
# Epoch 35/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 36/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0649 - top5_acc: 0.0000e+00
# Epoch 37/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0646 - top5_acc: 0.0000e+00
# Epoch 38/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0646 - top5_acc: 0.0000e+00
# Epoch 39/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0646 - top5_acc: 0.0000e+00
# Epoch 40/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0646 - top5_acc: 0.0000e+00
# Epoch 41/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0642 - top5_acc: 0.0000e+00
# Epoch 42/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0642 - top5_acc: 0.0000e+00
# Epoch 43/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0641 - top5_acc: 0.0000e+00
# Epoch 44/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00
# Epoch 45/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00
# Epoch 46/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00
# Epoch 47/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00
# Epoch 48/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00
# Epoch 49/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00
# Epoch 50/50
# 5837/5837 [==============================] - 29s 5ms/step - loss: nan - acc: 0.0637 - top5_acc: 0.0000e+00

# %%
model_final.save_weights('case4_full_exp_weights.h5')

# %%
y_test = to_categorical(y_test)

# %%
score = model_final.evaluate(x_test, y_test, verbose=1)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 1460/1460 [==============================] - 7s 5ms/step
# Test loss: nan
# Test accuracy: 0.06986301371904269

# %%
eval = np.c_[score[0],score[1],score[2]]
sc = np.array(eval)
np.savetxt("case4__full_lin_evaluate.txt", sc, delimiter=";")

# %%
history1 = np.c_[learning.history["loss"],learning.history['val_acc'],learning.history['val_top5_acc']]
hist = np.array(history1)
np.savetxt("case4__full_lin_hist1.txt", hist, delimiter=";")
